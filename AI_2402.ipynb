# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCalmTam/FUZZYLOGIC/blob/main/AI_2402.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip skfuzzy
# Out:
# ERROR: unknown command "skfuzzy"

# %%
pip skfuzzy

# %%
pip skfuzzy
# Out:
# ERROR: unknown command "skfuzzy"

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-fuzzy
#   Downloading scikit-fuzzy-0.4.2.tar.gz (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 41.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from scikit-fuzzy) (1.22.4)
# Requirement already satisfied: scipy>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from scikit-fuzzy) (1.7.3)
# Requirement already satisfied: networkx>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from scikit-fuzzy) (3.0)
# Building wheels for collected packages: scikit-fuzzy
#   Building wheel for scikit-fuzzy (setup.py) ... done
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=2f55ab8eb70effb401a9d260588a5213a214eff6cd4c345c2d1a04789fc82e28
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# Installing collected packages: scikit-fuzzy
# Successfully installed scikit-fuzzy-0.4.2

# %%
import numpy as np 
import skfuzzy as fuzz 
import matplotlib.pyplot as plt 
x = np.arange(30,81,1)

# %%
slow = fuzz.trimf(x,[30,30,50])

# %%
mediumfast = fuzz.trimf(x,[40,60,80])

# %%
fullspeed  = fuzz.trimf(x,[50,70,80])

# %%
plt.figure()

# %%
plt.plot(x,slow,'r',linewidth=1.5, label = ' slow')

# %%
plt.plot(x,mediumfast,'r',linewidth=1.5, label = ' slow')

# %%
plt.plot(x,fullspeed,'r',linewidth=1.5, label = ' slow')

# %%
plt.plot(x,mediumfast,'r',linewidth=1.5, label = ' slow')

# %%
plt.plot(x,slow,'r',linewidth=1.5, label = ' slow')
plt.plot(x,mediumfast,'r',linewidth=1.5, label = ' slow')
plt.plot(x,fullspeed,'r',linewidth=1.5, label = ' slow')

# %%
slow = fuzz.trapmf(x,[30,30,30,50])
mediumfast =  fuzz.trapmf(x,[40,60,60,80])
fullspeed  = fuzz.trapmf(x,[50,70,70,80])

# %%
plt.plot(x,slow,'r',linewidth=1.5, label = ' slow')
plt.plot(x,mediumfast,'blue',linewidth=1.5, label = ' slow')
plt.plot(x,fullspeed,'black',linewidth=1.5, label = ' slow')

# %%
slow = fuzz.gaussmf(x,30,5)
mediumfast = fuzz.gaussmf(x,40,5)
fullspeed = fuzz.gaussmf(x,50,5)
action = fuzz.gaussmf(x,60,5)

# %%
plt.plot(x,slow,'r',linewidth=1.5, label = ' slow')
plt.plot(x,mediumfast,'blue',linewidth=1.5, label = ' slow')
plt.plot(x,fullspeed,'black',linewidth=1.5, label = ' slow')

# %%
plt.plot(x,slow,'r',linewidth=1.5, label = ' slow')
plt.plot(x,mediumfast,'blue',linewidth=1.5, label = ' slow')
plt.plot(x,fullspeed,'black',linewidth=1.5, label = ' slow')
plt.plot(x,action,'green',linewidth=1.5, label = ' slow')

# %%
slow = fuzz.trapmf(x,[0,5,5,10])
mediumfast =  fuzz.trapmf(x,[,60,60,80])
fullspeed  = fuzz.trapmf(x,[50,70,70,80])

# %% [markdown]
# TIP IN RESTAURANT

# %%
import numpy as np 
import skfuzzy as fuzz 
import matplotlib.pyplot as plt 
from skfuzzy import control as ctrl
# Out:
#   File "<ipython-input-8-8f19dd2dad84>", line 1
#     pip install scikit-fuzzy
#         ^
# SyntaxError: invalid syntax

# %%
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip = ctrl.Antecedent(np.arange(10,31,1),'tip')

food['poor'] = fuzz.trimf(food.universe,[0,0,5])
food['average'] = fuzz.trimf(food.universe,[0,5,10])
food['good'] = fuzz.trimf(food.universe,[5,10,10])
service['poor'] = fuzz.trimf(service.universe,[0,0,5])
service['average'] = fuzz.trimf(service.universe,[0,5,10])
service['good'] = fuzz.trimf(service.universe,[5,10,10])
tip['less'] = fuzz.trimf(tip.universe,[10,10,20])
tip['normal'] = fuzz.trimf(tip.universe,[10,20,30])
tip['much'] = fuzz.trimf(tip.universe,[20,30,30])

food.view()
service.view()
tip.view()

# %%
food['poor'].view()

# %%
rule1 = ctrl.Rule(food['poor'] & service['poor'], tip['less'])
rule2 = ctrl.Rule(food['poor'] & service['average'], tip['less'])
rule3 = ctrl.Rule(food['poor'] & service['good'], tip['normal'])
rule4 = ctrl.Rule(food['average'] & service['poor'], tip['normal'])
rule5 = ctrl.Rule(food['average'] & service['average'], tip['normal'])
rule6 = ctrl.Rule(food['average'] & service['good'], tip['much'])
rule7 = ctrl.Rule(food['good'] & service['poor'], tip['normal'])
rule8 = ctrl.Rule(food['good'] & service['average'], tip['much'])
rule9 = ctrl.Rule(food['good'] & service['good'], tip['much'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-942b1641869c> in <module>
# ----> 1 rule1 = ctrl.Rule(food['poor'] & service['poor'], tip['less'])
#       2 rule2 = ctrl.Rule(food['poor'] & service['average'], tip['less'])
#       3 rule3 = ctrl.Rule(food['poor'] & service['good'], tip['normal'])
#       4 rule4 = ctrl.Rule(food['average'] & service['poor'], tip['normal'])
#       5 rule5 = ctrl.Rule(food['average'] & service['average'], tip['normal'])
#
# NameError: name 'ctrl' is not defined

# %%
tipping_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
tipping =ctrl.ControlSystemSimulation(tipping_ctrl)
tipping.input['food']=  6.1
tipping.input['service']= 9.2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-efc41bd3363a> in <module>
# ----> 1 tipping_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
#       2 tipping =ctrl.ControlSystemSimulation(tipping_ctrl)
#       3 tipping.input['food']=  6.1
#       4 tipping.input['service']= 9.2
#
# NameError: name 'ctrl' is not defined

# %%
tipping.compute()
print(tipping.output['tip'])
tip.view(sim=tipping)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-7b5dfcef0842> in <module>
# ----> 1 tipping.compute()
#       2 print(tipping.output['tip'])
#       3 tip.view(sim=tipping)
#
# /usr/local/lib/python3.8/dist-packages/skfuzzy/control/controlsystem.py in compute(self)
#     354         for antecedent in self.ctrl.antecedents:
#     355             if antecedent.input[self] is None:
# --> 356                 raise ValueError("All antecedents must have input values!")
#     357             CrispValueCalculator(antecedent, self).fuzz(antecedent.input[self])
#     358
#
# ValueError: All antecedents must have input values!

# %% [markdown]
# Cooking rice

# %%
import numpy as np 
import skfuzzy as fuzz 
import matplotlib.pyplot as plt 
from skfuzzy import control as ctrl

# %%
rice = ctrl.Antecedent(np.arange(0,180,1),'food')
time = ctrl.Antecedent(np.arange(2,2000,1),'service')
power = ctrl.Antecedent(np.arange(0,100,1),'tip')

rice['rit'] = fuzz.trimf(rice.universe,[200,200,])
rice['it'] = fuzz.trimf(rice.universe,[0,5,10])
rice['tb'] = fuzz.trimf(rice.universe,[5,10,10])
rice['n'] = fuzz.trimf(rice.universe,[0,0,5])
rice['rn'] = fuzz.trimf(rice.universe,[0,5,10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-34345616f06d> in <module>
#       3 power = ctrl.Antecedent(np.arange(0,100,1),'tip')
#       4
# ----> 5 rice['poor'] = fuzz.trimf(food.universe,[0,0,5])
#       6 rice['average'] = fuzz.trimf(food.universe,[0,5,10])
#       7 rice['good'] = fuzz.trimf(food.universe,[5,10,10])
#
# /usr/local/lib/python3.8/dist-packages/skfuzzy/control/fuzzyvariable.py in __setitem__(self, key, item)
#     104
#     105         if mf.size != self.universe.size:
# --> 106             raise ValueError("New membership function {0} must be equivalent "
#     107                              "in length to the universe variable.\n"
#     108                              "Expected {1}, got {2}.".format(
#
# ValueError: New membership function poor must be equivalent in length to the universe variable.
# Expected 180, got 11.
