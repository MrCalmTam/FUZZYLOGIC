# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCalmTam/FUZZYLOGIC/blob/main/AI_WEEK03_SANG_T6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
clear

# %%
#create a dateframe 
#load library 
import pandas as pd 
#cearte dataframe 
dataframe = pd.DataFrame()
#add colums 
dataframe['Name'] = ['Lemon','Apple','Banana']
dataframe['Price'] = [5,8,7]
dataframe['License'] = [False,True,True]
#show data 
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df = dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
df.describe()
# Out:
#           Price
# count  3.000000
# mean   6.666667
# std    1.527525
# min    5.000000
# 25%    6.000000
# 50%    7.000000
# 75%    7.500000
# max    8.000000

# %%
#loc loc - xem du lieu 

df.loc[(df.Price == 5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
list(df.License) #xem du lieu
# Out:
# [False, True, True]

# %%
df.loc[(df.Price == 5) |(df.Name == 'Banana')]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 2  Banana      7     True

# %%
df.loc[(df.Price == 5) | (df.Name == 'Banana'), ['Name','Price']]  # xem 2 cot can thiet
# Out:
#      Name  Price
# 0   Lemon      5
# 2  Banana      7

# %%
df.loc[(df.Price == 7) & (df.Name == 'Banana'), ['Name','Price']]  # xem 2 cot can thiet
# Out:
#      Name  Price
# 2  Banana      7

# %%
df.iloc[2]
# Out:
# Name       Banana
# Price           7
# License      True
# Name: 2, dtype: object

# %%
df.iloc[2]
type (df.iloc[2]) # xem kieu du lieu
# Out:
# pandas.core.series.Series

# %%
df.iloc[[2]]
# Out:
#      Name  Price  License
# 2  Banana      7     True

# %%
df.iloc[0:2] # tru du lieu cuoi cung ra ; 0:2 la hang
# Out:
#     Name  Price  License
# 0  Lemon      5    False
# 1  Apple      8     True

# %%
df.iloc[0:2,0:-1] # tru cot du lieu cuoi cung ra ; 0:2 la hang
# Out:
#     Name  Price
# 0  Lemon      5
# 1  Apple      8

# %%
df.iloc[0:2,-1] # chi lay cot cuoi cung ; 0:2 la hang
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
sum = df.Price.sum()
print(sum)
# Out:
# 20

# %%
sum = df['Price'].sum()
print(sum)
# Out:
# 20

# %%
max = df['Price'].max()
print(max)
# Out:
# 8

# %%
count = df.Price.count()
print(count)
# Out:
# 3

# %%
#create row data 
new = pd.Series(['Orange',10, True], index = ['Name', 'Price', 'License'])
# append row
dataframe.append(new, ignore_index= True)
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True
# 3  Orange     10     True

# %%
# append a colum 
dataframe['Location'] = ['USA', 'VN', 'SIN']
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True      SIN

# %%
# delete a row 
dataframe.drop(1, axis =0).head(10)
# Out:
#     Year      City       Sport      Discipline  NOC            Event  \
# 0   1924  Chamonix     Skating  Figure skating  AUT       individual
# 2   1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3   1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4   1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5   1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6   1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7   1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8   1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9   1924  Chamonix     Skating   Speed skating  FIN            1500m
# 10  1924  Chamonix     Skating   Speed skating  FIN            5000m
#
#    Event gender   Medal
# 0             M  Silver
# 2             X    Gold
# 3             M  Bronze
# 4             M    Gold
# 5             M  Silver
# 6             X  Silver
# 7             M    Gold
# ...

# %%
dataframe.drop('Location', axis=1).head()
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
#replace 
dataframe['Price'].replace(5,7).head(5)
# Out:
# 0    7
# 1    8
# 2    7
# Name: Price, dtype: int64

# %%
#rename colums 
dataframe.rename(columns ={'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False      USA
# 1   Apple     8     True       VN
# 2  Banana     7     True      SIN

# %%
# load library
import pandas as pd
# create url
url = '/content/medals.csv'
# load data
dataframe = pd.read_csv(url)
# show data
dataframe.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
#show data 
dataframe
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
dataframe.shape
# Out:
# (2311, 8)

# %%
df = dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          2311 non-null   int64
#  1   City          2311 non-null   object
#  2   Sport         2311 non-null   object
#  3   Discipline    2311 non-null   object
#  4   NOC           2311 non-null   object
#  5   Event         2311 non-null   object
#  6   Event gender  2311 non-null   object
#  7   Medal         2311 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 144.6+ KB

# %%
df.describe()
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
df.describe()
# std: phuong sai
# mean: gia tri trung binh
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
df.iloc[0:10] # ~[:10]
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# ...

# %%
df.iloc[[200,]]
# Out:
#      Year        City   Sport       Discipline  NOC       Event Event gender  \
# 200  1948  St. Moritz  Skiing  Nordic Combined  FIN  individual            M
#
#     Medal
# 200  Gold

# %%
df = df.set_index(df['NOC'])
df.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# ...

# %%
df.loc['USA']
# Out:
#      Year        City       Sport      Discipline  NOC                 Event  \
# NOC
# USA  1924    Chamonix  Ice Hockey      Ice Hockey  USA            ice hockey
# USA  1924    Chamonix     Skating  Figure skating  USA            individual
# USA  1924    Chamonix     Skating   Speed skating  USA                  500m
# USA  1924    Chamonix      Skiing     Ski Jumping  USA  K90 individual (70m)
# USA  1928  St. Moritz   Bobsleigh       Bobsleigh  USA              five-man
# ..    ...         ...         ...             ...  ...                   ...
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
#
#     Event gender   Medal
# NOC
# ...

# %%
df[df['NOC']=='CAN'].head(10)
# Out:
#      Year                    City       Sport      Discipline  NOC  \
# NOC
# CAN  1924                Chamonix  Ice Hockey      Ice Hockey  CAN
# CAN  1928              St. Moritz  Ice Hockey      Ice Hockey  CAN
# CAN  1932             Lake Placid  Ice Hockey      Ice Hockey  CAN
# CAN  1932             Lake Placid     Skating  Figure skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1936  Garmisch-Partenkirchen  Ice Hockey      Ice Hockey  CAN
#
#           Event Event gender   Medal
# NOC
# CAN  ice hockey            M    Gold
# CAN  ice hockey            M    Gold
# CAN  ice hockey            M    Gold
# CAN  individual            M  Bronze
# ...

# %%
df[(df['Year']>=1990)&(df['Year']<=2006) & (df['NOC']=='USA')&(df['Event gender']=='W')&(df['Medal']=='Gold')].head(10)
# Out:
#      Year         City       Sport      Discipline  NOC       Event  \
# NOC
# USA  1992  Albertville     Skating  Figure skating  USA  individual
# USA  1992  Albertville     Skating  Short Track S.  USA        500m
# USA  1992  Albertville     Skating   Speed skating  USA       1000m
# USA  1992  Albertville     Skating   Speed skating  USA        500m
# USA  1992  Albertville      Skiing  Freestyle Ski.  USA      moguls
# USA  1994  Lillehammer     Skating  Short Track S.  USA        500m
# USA  1994  Lillehammer     Skating   Speed skating  USA       1000m
# USA  1994  Lillehammer     Skating   Speed skating  USA        500m
# USA  1994  Lillehammer      Skiing   Alpine Skiing  USA     super-G
# USA  1998       Nagano  Ice Hockey      Ice Hockey  USA  ice hockey
#
#     Event gender Medal
# NOC
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# ...

# %%
df['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
df.count()
# Out:
# Year            2311
# City            2311
# Sport           2311
# Discipline      2311
# NOC             2311
# Event           2311
# Event gender    2311
# Medal           2311
# dtype: int64

# %%
df['NOC'].count()
# Out:
# 2311

# %%
df.drop('NOC', axis=1).head(10)
# Out:
#      Year      City       Sport      Discipline            Event Event gender  \
# NOC
# AUT  1924  Chamonix     Skating  Figure skating       individual            M
# AUT  1924  Chamonix     Skating  Figure skating       individual            W
# AUT  1924  Chamonix     Skating  Figure skating            pairs            X
# BEL  1924  Chamonix   Bobsleigh       Bobsleigh         four-man            M
# CAN  1924  Chamonix  Ice Hockey      Ice Hockey       ice hockey            M
# FIN  1924  Chamonix    Biathlon        Biathlon  military patrol            M
# FIN  1924  Chamonix     Skating  Figure skating            pairs            X
# FIN  1924  Chamonix     Skating   Speed skating           10000m            M
# FIN  1924  Chamonix     Skating   Speed skating           10000m            M
# FIN  1924  Chamonix     Skating   Speed skating            1500m            M
#
#       Medal
# NOC
# AUT  Silver
# AUT    Gold
# AUT    Gold
# BEL  Bronze
# CAN    Gold
# FIN  Silver
# ...

# %%
df.drop(df.columns[2:4], axis=1).head(10)
# Out:
#      Year      City  NOC            Event Event gender   Medal
# NOC
# AUT  1924  Chamonix  AUT       individual            M  Silver
# AUT  1924  Chamonix  AUT       individual            W    Gold
# AUT  1924  Chamonix  AUT            pairs            X    Gold
# BEL  1924  Chamonix  BEL         four-man            M  Bronze
# CAN  1924  Chamonix  CAN       ice hockey            M    Gold
# FIN  1924  Chamonix  FIN  military patrol            M  Silver
# FIN  1924  Chamonix  FIN            pairs            X  Silver
# FIN  1924  Chamonix  FIN           10000m            M    Gold
# FIN  1924  Chamonix  FIN           10000m            M  Silver
# FIN  1924  Chamonix  FIN            1500m            M    Gold

# %%
df[df['NOC']!='CAN'].head(10)
# Out:
#      Year      City      Sport      Discipline  NOC            Event  \
# NOC
# AUT  1924  Chamonix    Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix    Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix    Skating  Figure skating  AUT            pairs
# BEL  1924  Chamonix  Bobsleigh       Bobsleigh  BEL         four-man
# FIN  1924  Chamonix   Biathlon        Biathlon  FIN  military patrol
# FIN  1924  Chamonix    Skating  Figure skating  FIN            pairs
# FIN  1924  Chamonix    Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix    Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix    Skating   Speed skating  FIN            1500m
# FIN  1924  Chamonix    Skating   Speed skating  FIN            5000m
#
#     Event gender   Medal
# NOC
# AUT            M  Silver
# AUT            W    Gold
# AUT            X    Gold
# BEL            M  Bronze
# FIN            M  Silver
# FIN            X  Silver
# ...

# %%
df = pd.read_csv(url)
df.groupby('NOC').head(10)
# Out:
#       Year      City       Sport       Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT       individual
# 1     1924  Chamonix     Skating   Figure skating  AUT       individual
# 2     1924  Chamonix     Skating   Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...              ...  ...              ...
# 2231  2006     Turin    Biathlon         Biathlon  POL  15km mass start
# 2232  2006     Turin      Skiing  Cross Country S  POL             30km
# 2269  2006     Turin      Skiing        Snowboard  SVK  Snowboard Cross
# 2284  2006     Turin    Biathlon         Biathlon  UKR            7.5km
# 2285  2006     Turin     Skating   Figure skating  UKR      ice dancing
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
df.groupby('NOC').count()
# Out:
#      Year  City  Sport  Discipline  Event  Event gender  Medal
# NOC
# AUS     6     6      6           6      6             6      6
# AUT   185   185    185         185    185           185    185
# BEL     5     5      5           5      5             5      5
# BLR     6     6      6           6      6             6      6
# BUL     6     6      6           6      6             6      6
# CAN   119   119    119         119    119           119    119
# CHN    33    33     33          33     33            33     33
# CRO     7     7      7           7      7             7      7
# CZE    10    10     10          10     10            10     10
# DEN     1     1      1           1      1             1      1
# ESP     2     2      2           2      2             2      2
# EST     6     6      6           6      6             6      6
# EUA    19    19     19          19     19            19     19
# EUN    23    23     23          23     23            23     23
# ...

# %%
df.groupby(['Year','NOC']).head()
# Out:
#       Year      City       Sport      Discipline  NOC        Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT   individual
# 1     1924  Chamonix     Skating  Figure skating  AUT   individual
# 2     1924  Chamonix     Skating  Figure skating  AUT        pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL     four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN   ice hockey
# ...    ...       ...         ...             ...  ...          ...
# 2286  2006     Turin   Bobsleigh       Bobsleigh  USA      two-man
# 2287  2006     Turin     Curling         Curling  USA      curling
# 2288  2006     Turin  Ice Hockey      Ice Hockey  USA   ice hockey
# 2289  2006     Turin     Skating  Figure skating  USA  ice dancing
# 2290  2006     Turin     Skating  Figure skating  USA   individual
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# ...

# %%
df.groupby(['Year','NOC']).count()
# Out:
#           City  Sport  Discipline  Event  Event gender  Medal
# Year NOC
# 1924 AUT     3      3           3      3             3      3
#      BEL     1      1           1      1             1      1
#      CAN     1      1           1      1             1      1
#      FIN    11     11          11     11            11     11
#      FRA     3      3           3      3             3      3
# ...        ...    ...         ...    ...           ...    ...
# 2006 SUI    14     14          14     14            14     14
#      SVK     1      1           1      1             1      1
#      SWE    14     14          14     14            14     14
#      UKR     2      2           2      2             2      2
#      USA    25     25          25     25            25     25
#
# [328 rows x 6 columns]

# %%
data = pd.read_csv(url)

# %%
# apply a function
def uppercase(x):
  return x.upper()
data['Event'].apply(uppercase)[0:2311]
# Out:
# 0            INDIVIDUAL
# 1            INDIVIDUAL
# 2                 PAIRS
# 3              FOUR-MAN
# 4            ICE HOCKEY
#              ...
# 2306          HALF-PIPE
# 2307          HALF-PIPE
# 2308          HALF-PIPE
# 2309    SNOWBOARD CROSS
# 2310    SNOWBOARD CROSS
# Name: Event, Length: 2311, dtype: object

# %%
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...
